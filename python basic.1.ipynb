# %%
#print,hello world
print("Hello World")
print("Welcome to PDA")
# Out:
# Hello World
# Welcome to PDA

# %%
#indentation
print(" I have no indentation")
print(" I have indentation")
# Out:
#  I have no indentation
#  I have indentation

# %%
# taking input
s="ABC"
age=25
p="india"
print(s,age,p)
# Out:
# ABC 25 india

# %%
#taking multiple inputs
x,y,z=input("Enter three values:").split()
print("Total number of students:",x)
print("Total number of boys:",y)
print("Total number of girls:",z)
# Out:
# Enter three values: 213
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #taking multiple inputs
# ----> 2 x,y,z=input("Enter three values:").split()
#       3 print("Total number of students:",x)
#       4 print("Total number of boys:",y)
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
#python variables
x=55.7
s="Hello"
print(x)
print(s)
# Out:
# 55.7
# Hello

# %%
#type casting a variables
i=int(x)
s1=str(x)
print(i)
print(s1)
# Out:
# 55
# 55.7
